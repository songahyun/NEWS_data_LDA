# %% [markdown]
# ## 전처리

# %% [markdown]
# #### 1. 데이터 불러오기

# %%
# 데이터 불러오기

import pandas as pd

df = pd.read_csv("news_dataset_2025.csv")

# 데이터 백업
df_raw = df.copy()

print("원본 데이터 개수:", len(df))
# Out:
# 원본 데이터 개수: 600

# %% [markdown]
# #### 2. 중복 기사 제거

# %%
# 중복 기사 확인
df[df.duplicated(subset=['title','content'], keep=False)]
# Out:
#                                        title  \
# 13   자동차 개소세 30% 인하·소비 늘리면 추가 소득공제...효과 있을까?
# 14      올해 1.8% 저성장 전망..."필요시 추가 보강" 추경 가능성도
# 21            피해 키운 로컬라이저 책임론 부상...음성 파일은 완성
# 41                    트럼프 2기 출범…부산항 걱정·기대 교차
# 55                   “제2 판교”라더니…업무 용지 대폭 축소?
# 58                    경북도 “APEC 국회 사절단 파견해야”
# 62                   꽁꽁 얼어붙은 골목상권…소비진작 ‘안간힘’
# 63                    충청북도 “실사구시 정신으로 민생 집중”
# 66       [기록K] 제2공항 기본계획 고시…‘조류 충돌’ 최대 쟁점 전망
# 69                              노인 일자리는 진화 중
# 70                     왕궁축산단지, 에덴 프로젝트 ‘청신호’
# 72              “75살이 막내”…현실이 된 초고령 사회, 대책은?
# 73                         ‘풍어·안전 기원’ 초매식 열려
# 77               전북도, 내년 국가 예산 신규 사업 377개 발굴
# 78                특별법 통과됐지만…“정부 재정지원이 최종 과제”
# 95                  ‘어려운 시기’…경남도민 새해 바라는 것은?
# 110     올해 1.8% 저성장 전망..."필요시 추가 보강" 추경 가능성도
# 118  자동차 개소세 30% 인하·소비 늘리면 추가 소득공제...효과 있을까?
# 154                    왕궁축산단지, 에덴 프로젝트 ‘청신호’
# 161                   충청북도 “실사구시 정신으로 민생 집중”
# 164                   경북도 “APEC 국회 사절단 파견해야”
# 172                   트럼프 2기 출범…부산항 걱정·기대 교차
# 185                             노인 일자리는 진화 중
# 192             “75살이 막내”…현실이 된 초고령 사회, 대책은?
# 195               특별법 통과됐지만…“정부 재정지원이 최종 과제”
# 211                  “제2 판교”라더니…업무 용지 대폭 축소?
# 213           피해 키운 로컬라이저 책임론 부상...음성 파일은 완성
# 217              전북도, 내년 국가 예산 신규 사업 377개 발굴
# 220                 ‘어려운 시기’…경남도민 새해 바라는 것은?
# 221      [기록K] 제2공항 기본계획 고시…‘조류 충돌’ 최대 쟁점 전망
# 227                        ‘풍어·안전 기원’ 초매식 열려
# 235                  꽁꽁 얼어붙은 골목상권…소비진작 ‘안간힘’
# 270                             헌화 기다리는 어린이들
# 271                             헌화 기다리는 어린이들
# 272                             헌화 기다리는 어린이들
# 289              유가족 질문 듣는 박상우 장관과 나원오 수사본부장
# 296              유가족 질문 듣는 박상우 장관과 나원오 수사본부장
#
#                                                content                 date  \
# 13   상반기 소비 5% 이상 늘리면 20% 추가 소득공제 영세소상공인 점포 신용카드 금액...  2025-01-02 23:05:32
# 14   한은 1.9%, IMF·KDI 2.0% 전망…"탄핵정국 미반영" 정부, 상반기 67...  2025-01-02 23:04:21
# 21   [앵커] 제주항공 여객기 참사의 피해를 키운 원인으로 지목되는 로컬라이저 구조물의 ...  2025-01-02 22:31:48
합뉴스  https://n.news.naver.com/mnews/article/001/001...
# 271  연합뉴스  https://n.news.naver.com/mnews/article/001/001...
# 272  연합뉴스  https://n.news.naver.com/mnews/article/001/001...
# 289  연합뉴스  https://n.news.naver.com/mnews/article/001/001...
# 296  연합뉴스  https://n.news.naver.com/mnews/article/001/001...

# %%
# 중복 기사 제거 (같은 기사 중 최신 기사만 유지)
# 1.날짜 형식 변환
df['date'] = pd.to_datetime(df['date'])

# 2.title + content 기준 중복 제거
df = df.sort_values("date").drop_duplicates(subset=['title','content'], keep="last")

# 백업
df_deduplicated = df.copy()

print("중복 제거 후:", len(df))
# Out:
# 중복 제거 후: 581

# %% [markdown]
# #### 3. 언론사별 기사 개수 확인 및 기사가 13개 이상인 언론사만 필터링

# %%
# 언론사별 기사 개수 확인
df['press'].value_counts()
# Out:
# press
# 파이낸셜뉴스      55
# KBS         52
# 한국경제        46
# 매일경제        33
# 이데일리        32
# SBS Biz     29
# 부산일보        26
# 연합뉴스        22
# 서울경제        17
# 국제신문        13
# 세계일보        13
# 머니투데이       13
# 국민일보        12
# 아이뉴스24      12
# 한국일보        12
# TV조선        10
# 연합뉴스TV      10
# 조선일보        10
# 경향신문         9
# 데일리안         9
# 이코노미스트       9
# 뉴시스          9
# 아시아경제        9
# 디지털타임스       8
# 한겨레          8
# 매일신문         8
# 매경이코노미       7
# 한경비즈니스       7
# YTN          7
# 서울신문         6
# 코리아중앙데일리     6
# MBC          6
# MBN          6
# 문화일보         5
# 더팩트          5
# 뉴스1          4
# 헤럴드경제        4
# 한국경제TV       3
# 동아일보         3
# SBS          3
# 조세일보         3
# JTBC         3
# 대전일보         3
# 채널A          2
# 조선비즈         2
# 중앙일보         2
# 일간스포츠        1
# 동행미디어 시대     1
# 경기일보         1
# 전자신문         1
# 강원도민일보       1
# 강원일보         1
# 스포츠경향        1
# 노컷뉴스         1
# Name: count, dtype: int64

# %%
# 기사 13개 이상인 언론사만 필터링

press_counts = df['press'].value_counts()

valid_press = press_counts[press_counts >= 13].index

df = df[df['press'].isin(valid_press)]

# 백업
df_press_filtered = df.copy()

print("언론사 필터링 후:", len(df))
print("남은 언론사 수:", df['press'].nunique())
# Out:
# 언론사 필터링 후: 351
# 남은 언론사 수: 12

# %% [markdown]
# #### 4. 제목과 본문 결합

# %%
# 제목 + 본문 결합

df['text'] = df['title'].fillna('') + " " + df['content'].fillna('')

# 백업
df_text_combined = df.copy()

# %% [markdown]
# #### 5. 텍스트 정제

# %%
# 텍스트 정제(특수문자 / HTML / 이메일 / URL 제거)
import re

def clean_text(text):

    text = re.sub(r'<.*?>', ' ', text)           # html 태그 제거
    text = re.sub(r'http\S+|www\S+', ' ', text)  # url 제거
    text = re.sub(r'\S+@\S+', ' ', text)         # 이메일 제거
    text = re.sub(r'[^가-힣\s]', ' ', text)      # 특수문자 제거
    text = re.sub(r'\s+', ' ', text)             # 공백 정리

    return text.strip()


df['clean_text'] = df['text'].apply(clean_text)

# 백업
df_text_cleaned = df.copy()

# %%
# !pip install kiwipiepy
# Out:
# Requirement already satisfied: kiwipiepy in c:\users\songa\appdata\local\programs\python\python311\lib\site-packages (0.22.2)
# Requirement already satisfied: kiwipiepy_model<0.23,>=0.22 in c:\users\songa\appdata\local\programs\python\python311\lib\site-packages (from kiwipiepy) (0.22.1)
# Requirement already satisfied: numpy in c:\users\songa\appdata\local\programs\python\python311\lib\site-packages (from kiwipiepy) (2.2.6)
# Requirement already satisfied: tqdm in c:\users\songa\appdata\local\programs\python\python311\lib\site-packages (from kiwipiepy) (4.67.1)
# Requirement already satisfied: colorama in c:\users\songa\appdata\local\programs\python\python311\lib\site-packages (from tqdm->kiwipiepy) (0.4.6)
# WARNING: Ignoring invalid distribution ~ympy (C:\Users\songa\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (C:\Users\songa\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (C:\Users\songa\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### 6. 형태소 분석(명사+동사+형용사)

# %%
# 형태소 분석(명사 + 동사 + 형용사)
from kiwipiepy import Kiwi

kiwi = Kiwi()
target_pos = ["NNG", "NNP", "VV", "VA"]

def tokenize(text):

    tokens = []

    result = kiwi.analyze(text)[0][0]

    for token, pos, _, _ in result:
        if pos in target_pos:
            tokens.append(token)

    return tokens

df["tokens"] = df["clean_text"].apply(tokenize)

df_tokenized = df.copy()

# %% [markdown]
# #### 7. 불용어 제거

# %%
# 불용어 제거

stopwords = ['기자','사진','뉴스','연합뉴스','뉴시스','보도','관련','이번','대한','통해', '하다', '이다',
'지난','현재','이날','오전','오후','당시','이후','앞서','최근','정부','관계자','업계','측','대통령','국회','위원회',
'등','것','수','때','위해','경우','때문','대해','지난해','올해','내년', '년','월','일','억','만','천''파이낸셜뉴스',
'KBS','한국경제','매일경제','이데일리','SBS Biz','부산일보','연합뉴스','서울경제','머니투데이','세계일보','국제신문'
]

def remove_stopwords(tokens):
    
    return [t for t in tokens if t not in stopwords]

df['tokens'] = df['tokens'].apply(remove_stopwords)

df_stopwords_removed = df.copy()

# %%
df = df_stopwords_removed.copy()

# %%
# 추가적인 불용어 제거

stopwords = [
'가능','상황','수준','계획','내용','포함','실제','방안','검토','일각','입장','경우','관련','통해',

# 뉴스 문체 단어
'발표','조사','응답','보고','설명','강조','언급','진단','요청','건의',

# 일반 서술 단어
'전체','가운데','이전','이후','처음','주요','전반','핵심','본격','적극','철저',

# 추상적인 단어
'효과','역할','문제','요소','체계','기반','구성','구축','확보','강화','지원',

# 시간 표현
'작년','새해','연내','시기','기간','차례',

# 분석에 의미 약한 동사
'나타나','밝히','따르','보이','점치','내다보','늘리','줄이','높이','갖추','만들',

# 문맥 보조 단어
'대상','이용','통하','위하','대하'
]

df['tokens'] = df['tokens'].apply(remove_stopwords)
df_stopwords_removed2 = df.copy()

# %% [markdown]
# #### 8. 한 글자 토큰 및 숫자 토큰 제거

# %%
# 한 글자인 토큰 제거

def remove_single_char(tokens):

    return [t for t in tokens if len(t) > 1]


df['tokens'] = df['tokens'].apply(remove_single_char)

# 백업
df_single_removed = df.copy()

# 숫자 토큰 제거

def remove_numbers(tokens):

    return [t for t in tokens if not t.isdigit()]


df['tokens'] = df['tokens'].apply(remove_numbers)

# 최종 전처리 백업
df_preprocessed = df.copy()

print("최종 데이터 개수:", len(df_preprocessed))
# Out:
# 최종 데이터 개수: 351

# %% [markdown]
# #### 9. 최종 전처리 데이터 저장

# %%
# 최종 전처리 데이터 저장

df_preprocessed.to_csv("news_preprocessed_2025.csv", index=False)

# %% [markdown]
# #### 10. 최종 데이터 확인

# %%
# 데이터 확인
df = df.reset_index(drop=True)
df
# Out:
#                                            title  \
# 0               경기 침체에 금리 인하 가능성…하반기 대출 규제 더 세진다
# 1                                중기부에 AI전담 TF생긴다
# 2                   현대차그룹 전기차 5종, 美서 전기차 보조금 받는다
# 3                        4대금융 "견고한 신뢰 쌓아 위기 넘겠다"
# 4                김영록 전남지사, 여객기 사고 피해지원 특별법 제정 건의
# ..                                           ...
# 346                   ‘상반기에 올인’ 조기집행 총력, 1월부터 푼다
# 347               노르웨이 작년 신차 90%가 전기차…올해 100% 목표
# 348  전세보증금 5.7억 안 돌려준 19세도… '악성 임대인' 1177명 명단 공개
# 349                  테슬라 지난해 차량인도량 179만대…전년대비 감소
# 350             우리은행, 10년 이상 대상 희망퇴직.."최대 31개월치"
#
#                                                content                date  \
# 0    [2025 금융시장 대전망] <1>깐깐해지는 가계빚 관리 가계대출 증가 한도 70조... 2025-01-02 17:56:27
# 1    AI생산적용 中企 1.5%그쳐 제조현장 AI 활성화 돕고 스마트제조기업 육성 취지 ... 2025-01-02 17:58:11
# 2    현대차 아이오닉 9·기아 EV9 등 현지 EV 생산 본격화…IRA 수혜 '트럼프 2... 2025-01-02 17:58:14
# 3    주요 금융그룹, 비상경영 선언 회장들, 신년사서 일제히 "위기" 불확실성에 신뢰 구... 2025-01-02 17:58:21
# 4    (무안=연합뉴스) 형민우 기자 = 김영록 전남지사는 2일 무안국제공항 분향소를 찾은... 2025-01-02 17:58:54
# ..                                                 ...                 ...
# 346  [앵커] 올해 한국의 경제 성장률이 1.8%에 그칠 것으로 전망됐습니다. 2년 만에... 2025-01-02 23:16:06
# 347  테슬라 압도적 1위속 中 제조사들 점유율 10% 돌파 (브뤼셀=연합뉴스) 정빛나 특... 2025-01-02 23:21:36
# 348  안심전세포털에 이름·신상 공개 평균 47세, 1인당 16.1억 미반환 [서울경제] ... 2025-01-02 23:31:12
# 349  작년 4분기 차량인도 49만5천대…시장기대 밑돌아 (뉴욕=연합뉴스) 이지헌 특파원 ... 2025-01-02 23:33:51
# 350  우리은행이 1969년생 이후 직원들 대상으로 희망퇴직을 시행합니다. 오늘(2일) 금... 2025-01-02 23:54:13
#
#        press                                                url  \
# 0       서울경제  https://n.news.naver.com/mnews/article/011/000...
# 1       매일경제  https://n.news.naver.com/mnews/article/009/000...
# 2       이데일리  https://n.news.naver.com/mnews/article/018/000...
# 3       한국경제  https://n.news.naver.com/mnews/article/015/000...
# 4       연합뉴스  https://n.news.naver.com/mnews/article/001/001...
# ..       ...                                                ...
# 346      KBS  https://n.news.naver.com/mnews/article/056/001...
# 347     연합뉴스  https://n.news.naver.com/mnews/article/001/001...
# 348     서울경제  https://n.news.naver.com/mnews/article/011/000...
# 349     연합뉴스  https://n.news.naver.com/mnews/article/001/001...
# 350  SBS Biz  https://n.news.naver.com/mnews/article/374/000...
#
#                                                   text  \
# 0    경기 침체에 금리 인하 가능성…하반기 대출 규제 더 세진다 [2025 금융시장 대전...
# 1    중기부에 AI전담 TF생긴다 AI생산적용 中企 1.5%그쳐 제조현장 AI 활성화 돕...
